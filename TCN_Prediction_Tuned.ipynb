# %%
import pandas as pd
# !pip install yahoo_fin --upgrade
import yahoo_fin
import numpy as np
from yahoo_fin.stock_info import get_data
import yfinance as yf

import math, time
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import torch
from torch import nn, optim
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt
import matplotlib as mpl
# Out:
# Collecting yahoo_fin
#   Downloading yahoo_fin-0.8.9.1-py3-none-any.whl (10 kB)
# Collecting requests-html (from yahoo_fin)
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Collecting feedparser (from yahoo_fin)
#   Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from yahoo_fin) (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from yahoo_fin) (2.0.3)
# Collecting sgmllib3k (from feedparser->yahoo_fin)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->yahoo_fin) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->yahoo_fin) (2024.2.2)
# Collecting pyquery (from requests-html->yahoo_fin)
#   Downloading pyquery-2.0.0-py3-none-any.whl (22 kB)
# Collecting fake-useragent (from requests-html->yahoo_fin)
#   Downloading fake_useragent-1.5.1-py3-none-any.whl (17 kB)
# Collecting parse (from requests-html->yahoo_fin)
#   Downloading parse-1.20.1-py2.py3-none-any.whl (20 kB)
# Collecting bs4 (from requests-html->yahoo_fin)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Collecting w3lib (from requests-html->yahoo_fin)
#   Downloading w3lib-2.1.2-py3-none-any.whl (21 kB)
# Collecting pyppeteer>=0.0.14 (from requests-html->yahoo_fin)
#   Downloading pyppeteer-2.0.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 4.5 MB/s eta 0:00:00
# Collecting appdirs<2.0.0,>=1.4.3 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (7.1.0)
# Collecting pyee<12.0.0,>=11.0.0 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Downloading pyee-11.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.66.4)
# Collecting urllib3<3,>=1.21.1 (from requests->yahoo_fin)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 7.5 MB/s eta 0:00:00
# Collecting websockets<11.0,>=10.0 (from pyppeteer>=0.0.14->requests-html->yahoo_fin)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->yahoo_fin) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->requests-html->yahoo_fin) (4.12.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html->yahoo_fin) (4.9.4)
# Collecting cssselect>=1.2.0 (from pyquery->requests-html->yahoo_fin)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.18.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.11.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.5)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6049 sha256=a29bcafa2340fcd316a35c3731abc81d9b790040fe3fbe7b1aa2d9ddcd77e8dd
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, parse, fake-useragent, appdirs, websockets, w3lib, urllib3, pyee, feedparser, cssselect, pyquery, pyppeteer, bs4, requests-html, yahoo_fin
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# Successfully installed appdirs-1.4.4 bs4-0.0.2 cssselect-1.2.0 fake-useragent-1.5.1 feedparser-6.0.11 parse-1.20.1 pyee-11.1.0 pyppeteer-2.0.0 pyquery-2.0.0 requests-html-0.10.0 sgmllib3k-1.0.0 urllib3-1.26.18 w3lib-2.1.2 websockets-10.4 yahoo_fin-0.8.9.1

# %%
np.random.seed(42)

# Set random seed for PyTorch
torch.manual_seed(42)

# %%
#ENTER TICKER SYMBOL AND PULL BASIC COMPANY INFORMATION
stock_ticker = "AMZN"

#industry and sector information
stock = yf.Ticker(stock_ticker)
industry = stock.info['industry']
sector = stock.info['sector']

print(f"Ticker Symbol: {stock_ticker}")
print(f"Industry: {industry}")
print(f"Sector: {sector}")
# Out:
# Ticker Symbol: AMZN
# Industry: Internet Retail
# Sector: Consumer Cyclical

# %%
#PULL DATA AND ENGINEERED FEATURES USING YAHOO FINANCE API
stock_data = get_data(stock_ticker, start_date="01/01/2010", end_date="12/31/2019", index_as_date=True, interval="1d")

#log returns
stock_data['Log_Return'] = np.log(stock_data['close'] / stock_data['close'].shift(1))

# 20 and 50 day moving day averages
stock_data['SMA_20'] = stock_data['close'].rolling(window=20).mean()
stock_data['SMA_50'] = stock_data['close'].rolling(window=50).mean()

#exponential moving average/EMA
stock_data['EMA_20'] = stock_data['close'].ewm(span=20, adjust=False).mean()

#relative strength index/RSI
window_length = 14
delta = stock_data['close'].diff()
up = delta.clip(lower=0)
down = -1 * delta.clip(upper=0)
ema_up = up.ewm(com=window_length - 1, adjust=True, min_periods=window_length).mean()
ema_down = down.ewm(com=window_length - 1, adjust=True, min_periods=window_length).mean()
rs = ema_up / ema_down
stock_data['RSI'] = 100 - (100 / (1 + rs))

#technical indicators
stock_data['MACD'] = stock_data['close'].ewm(span=12).mean() - stock_data['close'].ewm(span=26).mean()
stock_data['MACD_Signal'] = stock_data['MACD'].ewm(span=9).mean()
stock_data['Stochastic_%K'] = stock_data['close'].rolling(window=14).apply(lambda x: (x[-1] - x.min()) / (x.max() - x.min()), raw=True)
stock_data['Stochastic_%D'] = stock_data['Stochastic_%K'].rolling(window=3).mean()

#volume indicators
stock_data['Volume_SMA_20'] = stock_data['volume'].rolling(window=20).mean()
stock_data['Volume_Ratio'] = stock_data['volume'] / stock_data['Volume_SMA_20']

#volatility indicators
stock_data['Daily_Return_Volatility'] = stock_data['Log_Return'].rolling(window=14).std() * np.sqrt(252)
stock_data['Garman_Klass_Volatility'] = np.sqrt(252 * 0.5 * ((np.log(stock_data['close'] / stock_data['close'].shift(1)))**2).rolling(window=14).mean())

#momentum and trend indicators
stock_data['Price_Momentum'] = stock_data['close'].pct_change(periods=14)
stock_data['Rate_of_Change'] = stock_data['close'].pct_change(periods=9)
stock_data['Trend'] = np.where(stock_data['close'] > stock_data['close'].shift(1), 1, -1)

# seasonality indicators
stock_data['Day_of_Week'] = stock_data.index.dayofweek
stock_data['Month'] = stock_data.index.month

# information ratio
stock_data['info_ratio'] = stock_data['close'] / stock_data['close'].shift(14) / stock_data['Daily_Return_Volatility']

stock_data['close_change'] = stock_data['close'] - stock_data['close'].shift(1)
stock_data['range'] = stock_data['high'] - stock_data['low']
stock_data['ATR'] = stock_data['range'].rolling(window=14).mean()
stock_data['stoc_oscillator'] = (stock_data['close'] - stock_data['low'].rolling(window=14).min()) / (stock_data['high'].rolling(window=14).max() - stock_data['low'].rolling(window=14).min())

stock_data['cum_ret'] = stock_data['close'] / stock_data.iloc[-1]['open']

#data head
stock_data = stock_data.sort_index(ascending=False).dropna().iloc[::-1]
print(stock_data.head(100))
# Out:
#               open    high     low   close  adjclose     volume ticker  \
# 2010-03-16  6.5620  6.6145  6.5250  6.5895    6.5895   82650000   AMZN
# 2010-03-17  6.6205  6.6345  6.5610  6.5670    6.5670   87176000   AMZN
# 2010-03-18  6.5510  6.6425  6.5220  6.6380    6.6380  100426000   AMZN
# 2010-03-19  6.6855  6.6855  6.4830  6.5175    6.5175  178100000   AMZN
# 2010-03-22  6.5100  6.5480  6.4320  6.5235    6.5235  107668000   AMZN
# ...            ...     ...     ...     ...       ...        ...    ...
# 2010-07-30  5.7765  5.9370  5.7255  5.8945    5.8945  141550000   AMZN
# 2010-08-02  5.9575  6.0190  5.8785  6.0035    6.0035  108874000   AMZN
# 2010-08-03  6.0000  6.1435  5.9840  6.1210    6.1210  119076000   AMZN
# 2010-08-04  6.1530  6.4235  6.1500  6.3790    6.3790  185416000   AMZN
# 2010-08-05  6.3385  6.4000  6.2910  6.3915    6.3915   85646000   AMZN
#
#             Log_Return    SMA_20   SMA_50  ...  Rate_of_Change  Trend  \
# 2010-03-16    0.005021  6.236600  6.21460  ...        0.046866      1
# 2010-03-17   -0.003420  6.274175  6.21204  ...        0.021863     -1
# 2010-03-18    0.010754  6.310875  6.21011  ...        0.029866      1
# 2010-03-19   -0.018320  6.342950  6.20821  ...        0.001845     -1
# 2010-03-22    0.000920  6.374100  6.20868  ...        0.012809      1
# ...                ...       ...      ...  ...             ...    ...
# 2010-07-30    0.008775  5.892350  6.00936  ...       -0.017092      1
# 2010-08-02    0.018323  5.919675  6.00972  ...       -0.000250      1
# 2010-08-03    0.019383  5.950575  6.00942  ...        0.042493      1
# 2010-08-04    0.041286  5.985950  6.01488  ...        0.062547      1
# 2010-08-05    0.001958  6.014975  6.01785  ...        0.075376      1
#
#             Day_of_Week  Month  info_ratio  close_change   range       ATR  \
# 2010-03-16            1      3    4.111622        0.0330  0.0895  0.153143
# 2010-03-17            2      3    4.320867       -0.0225  0.0735  0.149500
# 2010-03-18            3      3    4.379220        0.0710  0.1205  0.149429
# 2010-03-19            4      3    5.384695       -0.1205  0.2025  0.138429
# 2010-03-22            0      3    5.374463        0.0060  0.1160  0.137607
# ...                 ...    ...         ...           ...     ...       ...
# 2010-07-30            4      7    3.732885        0.0515  0.2115  0.206357
# 2010-08-02            0      8    4.221069        0.1090  0.1405  0.200036
# 2010-08-03            1      8    4.014295        0.1175  0.1595  0.203286
# 2010-08-04            2      8    3.491917        0.2580  0.2735  0.211321
# 2010-08-05            3      8    4.157701        0.0125  0.1090  0.205143
#
#             stoc_oscillator   cum_ret
# 2010-03-16         0.868665  0.070326
# 2010-03-17         0.833721  0.070085
# 2010-03-18         0.913617  0.070843
# 2010-03-19         0.605936  0.069557
# 2010-03-22         0.618219  0.069621
# ...                     ...       ...
# 2010-07-30         0.633648  0.062908
# 2010-08-02         0.794986  0.064072
# 2010-08-03         0.973638  0.065326
# 2010-08-04         0.960741  0.068079
# 2010-08-05         0.971769  0.068212
#
# [100 rows x 31 columns]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math, time
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from torch.utils.data import TensorDataset, DataLoader

# %%
#preprocess data
stock_data = stock_data.drop(columns=['ticker'])
scaler = MinMaxScaler(feature_range=(-1, 1)).set_output(transform="pandas")
stock_data_time = scaler.fit_transform(stock_data)
scaler = MinMaxScaler(feature_range=(-1, 1)).set_output(transform="pandas")
scaler.fit(stock_data[['close']])
stock_data_time = stock_data_time.dropna()

print(stock_data_time.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2466 entries, 2010-03-16 to 2019-12-30
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   open                     2466 non-null   float64
#  1   high                     2466 non-null   float64
#  2   low                      2466 non-null   float64
#  3   close                    2466 non-null   float64
#  4   adjclose                 2466 non-null   float64
#  5   volume                   2466 non-null   float64
#  6   Log_Return               2466 non-null   float64
#  7   SMA_20                   2466 non-null   float64
#  8   SMA_50                   2466 non-null   float64
#  9   EMA_20                   2466 non-null   float64
#  10  RSI                      2466 non-null   float64
#  11  MACD                     2466 non-null   float64
#  12  MACD_Signal              2466 non-null   float64
#  13  Stochastic_%K            2466 non-null   float64
#  14  Stochastic_%D            2466 non-null   float64
#  15  Volume_SMA_20            2466 non-null   float64
#  16  Volume_Ratio             2466 non-null   float64
#  17  Daily_Return_Volatility  2466 non-null   float64
#  18  Garman_Klass_Volatility  2466 non-null   float64
#  19  Price_Momentum           2466 non-null   float64
#  20  Rate_of_Change           2466 non-null   float64
#  21  Trend                    2466 non-null   float64
#  22  Day_of_Week              2466 non-null   float64
#  23  Month                    2466 non-null   float64
#  24  info_ratio               2466 non-null   float64
#  25  close_change             2466 non-null   float64
#  26  range                    2466 non-null   float64
#  27  ATR                      2466 non-null   float64
#  28  stoc_oscillator          2466 non-null   float64
#  29  cum_ret                  2466 non-null   float64
# dtypes: float64(30)
# memory usage: 597.2 KB
# None

# %%
def load_data(stock, look_back):
    close_idx = stock.columns.get_loc('close')
    data_raw = stock.values
    data = []

    for index in range(len(data_raw) - look_back):
        data.append(data_raw[index: index + look_back])

    data = np.array(data)

    test_size = int(0.2 * len(data))
    x_train = data[:-test_size, :-1, :]
    y_train = data[:-test_size, -1, close_idx]
    prev_close_train = data[:-test_size, -2, close_idx]

    x_test = data[-test_size:, :-1]
    y_test = data[-test_size:, -1, close_idx]
    prev_close_test = data[-test_size:, -2, close_idx]
    x_train = np.array(x_train, dtype=np.float32)
    y_train = np.array(y_train, dtype=np.float32)
    prev_close_train = np.array(prev_close_train, dtype=np.float32)
    x_test = np.array(x_test, dtype=np.float32)
    y_test = np.array(y_test, dtype=np.float32)
    prev_close_test = np.array(prev_close_test, dtype=np.float32)

    x_train = torch.from_numpy(x_train).type(torch.Tensor)
    y_train = torch.from_numpy(y_train).type(torch.Tensor)
    prev_close_train = torch.from_numpy(prev_close_train).type(torch.Tensor)

    x_test = torch.from_numpy(x_test).type(torch.Tensor)
    y_test = torch.from_numpy(y_test).type(torch.Tensor)
    prev_close_test = torch.from_numpy(prev_close_test).type(torch.Tensor)

    return [x_train, y_train, prev_close_train, x_test, y_test, prev_close_test]

look_back = 61
x_train, y_train, prev_close_train, x_test, y_test, prev_close_test = load_data(stock_data_time, look_back)

print('x_train.shape =', x_train.shape)
print('y_train.shape =', y_train.shape)
print('x_test.shape =', x_test.shape)
print('y_test.shape =', y_test.shape)

batch_size = 32
train_loader = DataLoader(TensorDataset(x_train, prev_close_train, y_train), batch_size=batch_size, shuffle=True)
test_loader = DataLoader(TensorDataset(x_test, prev_close_test, y_test), batch_size=batch_size, shuffle=True)
# Out:
# x_train.shape = torch.Size([1924, 60, 30])
# y_train.shape = torch.Size([1924])
# x_test.shape = torch.Size([481, 60, 30])
# y_test.shape = torch.Size([481])

# %%
class Chomp1d(nn.Module):
    def __init__(self, chomp_size):
        super(Chomp1d, self).__init__()
        self.chomp_size = chomp_size

    def forward(self, x):
        return x[:, :, :-self.chomp_size].contiguous()

# %%
class TemporalBlock(nn.Module):
    def __init__(self, n_inputs, n_outputs, kernel_size, stride, dilation, dropout=0.2):
        super(TemporalBlock, self).__init__()
        padding = (kernel_size - 1) * dilation
        self.conv1 = nn.Conv1d(n_inputs, n_outputs, kernel_size, stride=stride, padding=padding, dilation=dilation)
        self.chomp1 = Chomp1d(padding)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout)

        self.conv2 = nn.Conv1d(n_outputs, n_outputs, kernel_size, stride=stride, padding=padding, dilation=dilation)
        self.chomp2 = Chomp1d(padding)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout)

        self.net = nn.Sequential(self.conv1, self.chomp1, self.relu1, self.dropout1,
                                 self.conv2, self.chomp2, self.relu2, self.dropout2)

        self.downsample = nn.Conv1d(n_inputs, n_outputs, 1) if n_inputs != n_outputs else None
        self.relu = nn.ReLU()
        self.init_weights()

    def init_weights(self):
        self.conv1.weight.data.normal_(0, 0.01)
        self.conv2.weight.data.normal_(0, 0.01)
        if self.downsample is not None:
            self.downsample.weight.data.normal_(0, 0.01)

    def forward(self, x):
        out = self.net(x)
        res = x if self.downsample is None else self.downsample(x)
        return self.relu(out + res)

class TemporalConvNet(nn.Module):
    def __init__(self, num_inputs, num_channels, kernel_size=2, dropout=0.2):
        super(TemporalConvNet, self).__init__()
        layers = []
        num_levels = len(num_channels)
        for i in range(num_levels):
            dilation_size = 2 ** i
            in_channels = num_inputs if i == 0 else num_channels[i-1]
            out_channels = num_channels[i]
            layers += [TemporalBlock(in_channels, out_channels, kernel_size, stride=1, dilation=dilation_size, dropout=dropout)]

        self.network = nn.Sequential(*layers)

    def forward(self, x):
        return self.network(x)

class TCN(nn.Module):
    def __init__(self, input_size, output_size, num_channels, kernel_size, dropout):
        super(TCN, self).__init__()
        self.tcn = TemporalConvNet(input_size, num_channels, kernel_size=kernel_size, dropout=dropout)
        self.linear = nn.Linear(num_channels[-1] + 1, output_size)  # Add 1 for prev_close

    def forward(self, x, prev_close):
        x = x.permute(0, 2, 1)
        y = self.tcn(x)
        y = y[:, :, -1]
        y = torch.cat((y, prev_close.unsqueeze(1)), dim=1)
        y = self.linear(y)
        return y

# %%
def train(model, device, train_loader, optimizer, epoch, loss_function):
    model.train()
    train_loss = 0
    for batch_idx, (data, prev_close, target) in enumerate(train_loader):
        data, prev_close, target = data.to(device), prev_close.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data, prev_close)
        loss = loss_function(output.squeeze(), target)
        train_loss += loss.item()
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 0.7)
        optimizer.step()
        if (batch_idx + 1) % (len(train_loader) // 4) == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)], Batch Loss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()
            ))
    return train_loss / len(train_loader)

# %%
def test(model, device, test_loader, epoch, loss_function):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for data, prev_close, target in test_loader:
            data, prev_close, target = data.to(device), prev_close.to(device), target.to(device)
            output = model(data, prev_close)
            test_loss += loss_function(output.squeeze(), target).item()
    print('Test epoch: {}, Test batch loss: {:.4f}'.format(
        epoch, test_loss / len(test_loader)
    ))
    return test_loss / len(test_loader)

# %%
#Model parameters
input_size = x_train.shape[2]
output_size = 1
num_channels = [64, 64, 64, 64]  #number of channels in each layer
kernel_size = 13 #increase to increase model recognition of temporal patterns
dropout = 0.2
num_epochs = 75
device = 'cpu'

model = TCN(input_size, output_size, num_channels, kernel_size, dropout).to(device)
loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# %%
print(model)
print(len(list(model.parameters())))
for i in range(len(list(model.parameters()))):
    print(list(model.parameters())[i].size())

train_losses = []
val_losses = []
for epoch in range(1, num_epochs + 1):
    train_losses.append(train(model, device, train_loader, optimizer, epoch, loss_fn))
    val_losses.append(test(model, device, test_loader, epoch, loss_fn))
    if val_losses[-1] == min(val_losses):
        torch.save(model.state_dict(), 'model_weights.pth')


plt.plot(np.arange(1, num_epochs + 1), train_losses, label=r'train')
plt.plot(np.arange(1, num_epochs + 1), val_losses, label=r'val')
plt.legend()
# Out:
# TCN(
#   (tcn): TemporalConvNet(
#     (network): Sequential(
#       (0): TemporalBlock(
#         (conv1): Conv1d(30, 64, kernel_size=(13,), stride=(1,), padding=(12,))
#         (chomp1): Chomp1d()
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (conv2): Conv1d(64, 64, kernel_size=(13,), stride=(1,), padding=(12,))
#         (chomp2): Chomp1d()
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (net): Sequential(
#           (0): Conv1d(30, 64, kernel_size=(13,), stride=(1,), padding=(12,))
#           (1): Chomp1d()
#           (2): ReLU()
#           (3): Dropout(p=0.2, inplace=False)
#           (4): Conv1d(64, 64, kernel_size=(13,), stride=(1,), padding=(12,))
#           (5): Chomp1d()
#           (6): ReLU()
#           (7): Dropout(p=0.2, inplace=False)
#         )
#         (downsample): Conv1d(30, 64, kernel_size=(1,), stride=(1,))
#         (relu): ReLU()
#       )
#       (1): TemporalBlock(
#         (conv1): Conv1d(64, 64, kernel_size=(13,), stride=(1,), padding=(24,), dilation=(2,))
#         (chomp1): Chomp1d()
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (conv2): Conv1d(64, 64, kernel_size=(13,), stride=(1,), padding=(24,), dilation=(2,))
#         (chomp2): Chomp1d()
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (net): Sequential(
#           (0): Conv1d(64, 64, kernel_size=(13,), stride=(1,), padding=(24,), dilation=(2,))
#           (1): Chomp1d()
#           (2): ReLU()
#           (3): Dropout(p=0.2, inplace=False)
#           (4): Conv1d(64, 64, kernel_size=(13,), stride=(1,), padding=(24,), dilation=(2,))
#           (5): Chomp1d()
#           (6): ReLU()
#           (7): Dropout(p=0.2, inplace=False)
#         )
#         (relu): ReLU()
#       )
#       (2): TemporalBlock(
#         (conv1): Conv1d(64, 64, kernel_size=(13,), stride=(1,), padding=(48,), dilation=(4,))
#         (chomp1): Chomp1d()
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (conv2): Conv1d(64, 64, kernel_size=(13,), stride=(1,), padding=(48,), dilation=(4,))
#         (chomp2): Chomp1d()
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (net): Sequential(
#           (0): Conv1d(64, 64, kernel_size=(13,), stride=(1,), padding=(48,), dilation=(4,))
#           (1): Chomp1d()
#           (2): ReLU()
#           (3): Dropout(p=0.2, inplace=False)
#           (4): Conv1d(64, 64, kernel_size=(13,), stride=(1,), padding=(48,), dilation=(4,))
#           (5): Chomp1d()
#           (6): ReLU()
#           (7): Dropout(p=0.2, inplace=False)
#         )
#         (relu): ReLU()
#       )
#       (3): TemporalBlock(
#         (conv1): Conv1d(64, 64, kernel_size=(13,), stride=(1,), padding=(96,), dilation=(8,))
#         (chomp1): Chomp1d()
#         (relu1): ReLU()
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (conv2): Conv1d(64, 64, kernel_size=(13,), stride=(1,), padding=(96,), dilation=(8,))
#         (chomp2): Chomp1d()
#         (relu2): ReLU()
#         (dropout2): Dropout(p=0.2, inplace=False)
#         (net): Sequential(
#           (0): Conv1d(64, 64, kernel_size=(13,), stride=(1,), padding=(96,), dilation=(8,))
#           (1): Chomp1d()
#           (2): ReLU()
#           (3): Dropout(p=0.2, inplace=False)
#           (4): Conv1d(64, 64, kernel_size=(13,), stride=(1,), padding=(96,), dilation=(8,))
#           (5): Chomp1d()
#           (6): ReLU()
#           (7): Dropout(p=0.2, inplace=False)
#         )
#         (relu): ReLU()
#       )
#     )
#   )
#   (linear): Linear(in_features=65, out_features=1, bias=True)
# )
# 20
# torch.Size([64, 30, 13])
# torch.Size([64])
# torch.Size([64, 64, 13])
# torch.Size([64])
# torch.Size([64, 30, 1])
# torch.Size([64])
# torch.Size([64, 64, 13])
# torch.Size([64])
# torch.Size([64, 64, 13])
# torch.Size([64])
# torch.Size([64, 64, 13])
# torch.Size([64])
# torch.Size([64, 64, 13])
# torch.Size([64])
# torch.Size([64, 64, 13])
# torch.Size([64])
# torch.Size([64, 64, 13])
# torch.Size([64])
# torch.Size([1, 65])
# torch.Size([1])
# Train Epoch: 1 [448/1924 (23%)], Batch Loss: 0.189181
# Train Epoch: 1 [928/1924 (48%)], Batch Loss: 0.027475
# Train Epoch: 1 [1408/1924 (72%)], Batch Loss: 0.012839
# Train Epoch: 1 [1888/1924 (97%)], Batch Loss: 0.006847
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Test epoch: 1, Test batch loss: 0.5518
# Train Epoch: 2 [448/1924 (23%)], Batch Loss: 0.005830
# Train Epoch: 2 [928/1924 (48%)], Batch Loss: 0.004997
# Train Epoch: 2 [1408/1924 (72%)], Batch Loss: 0.004532
# Train Epoch: 2 [1888/1924 (97%)], Batch Loss: 0.004367
# Test epoch: 2, Test batch loss: 0.2713
# Train Epoch: 3 [448/1924 (23%)], Batch Loss: 0.005177
# Train Epoch: 3 [928/1924 (48%)], Batch Loss: 0.004617
# Train Epoch: 3 [1408/1924 (72%)], Batch Loss: 0.004168
# Train Epoch: 3 [1888/1924 (97%)], Batch Loss: 0.004037
# Test epoch: 3, Test batch loss: 0.1397
# Train Epoch: 4 [448/1924 (23%)], Batch Loss: 0.003013
# Train Epoch: 4 [928/1924 (48%)], Batch Loss: 0.005508
# Train Epoch: 4 [1408/1924 (72%)], Batch Loss: 0.003009
# Train Epoch: 4 [1888/1924 (97%)], Batch Loss: 0.004397
# Test epoch: 4, Test batch loss: 0.0934
# Train Epoch: 5 [448/1924 (23%)], Batch Loss: 0.003364
# Train Epoch: 5 [928/1924 (48%)], Batch Loss: 0.003840
# Train Epoch: 5 [1408/1924 (72%)], Batch Loss: 0.003818
# Train Epoch: 5 [1888/1924 (97%)], Batch Loss: 0.002128
# Test epoch: 5, Test batch loss: 0.0841
# Train Epoch: 6 [448/1924 (23%)], Batch Loss: 0.002412
# Train Epoch: 6 [928/1924 (48%)], Batch Loss: 0.002069
# Train Epoch: 6 [1408/1924 (72%)], Batch Loss: 0.003588
# Train Epoch: 6 [1888/1924 (97%)], Batch Loss: 0.002061
# Test epoch: 6, Test batch loss: 0.0630
# Train Epoch: 7 [448/1924 (23%)], Batch Loss: 0.001538
# Train Epoch: 7 [928/1924 (48%)], Batch Loss: 0.003032
# Train Epoch: 7 [1408/1924 (72%)], Batch Loss: 0.002891
# Train Epoch: 7 [1888/1924 (97%)], Batch Loss: 0.002466
# Test epoch: 7, Test batch loss: 0.0522
# Train Epoch: 8 [448/1924 (23%)], Batch Loss: 0.001000
# Train Epoch: 8 [928/1924 (48%)], Batch Loss: 0.002733
# Train Epoch: 8 [1408/1924 (72%)], Batch Loss: 0.002846
# Train Epoch: 8 [1888/1924 (97%)], Batch Loss: 0.002256
# Test epoch: 8, Test batch loss: 0.0592
# Train Epoch: 9 [448/1924 (23%)], Batch Loss: 0.003183
# Train Epoch: 9 [928/1924 (48%)], Batch Loss: 0.002532
# Train Epoch: 9 [1408/1924 (72%)], Batch Loss: 0.001672
# Train Epoch: 9 [1888/1924 (97%)], Batch Loss: 0.002092
# Test epoch: 9, Test batch loss: 0.0482
# Train Epoch: 10 [448/1924 (23%)], Batch Loss: 0.001544
# Train Epoch: 10 [928/1924 (48%)], Batch Loss: 0.001171
# Train Epoch: 10 [1408/1924 (72%)], Batch Loss: 0.001469
# Train Epoch: 10 [1888/1924 (97%)], Batch Loss: 0.001824
# Test epoch: 10, Test batch loss: 0.0428
# Train Epoch: 11 [448/1924 (23%)], Batch Loss: 0.005291
# Train Epoch: 11 [928/1924 (48%)], Batch Loss: 0.002169
# Train Epoch: 11 [1408/1924 (72%)], Batch Loss: 0.001961
# Train Epoch: 11 [1888/1924 (97%)], Batch Loss: 0.002500
# Test epoch: 11, Test batch loss: 0.0450
# Train Epoch: 12 [448/1924 (23%)], Batch Loss: 0.001653
# Train Epoch: 12 [928/1924 (48%)], Batch Loss: 0.001953
# Train Epoch: 12 [1408/1924 (72%)], Batch Loss: 0.002945
# Train Epoch: 12 [1888/1924 (97%)], Batch Loss: 0.002473
# Test epoch: 12, Test batch loss: 0.0324
# Train Epoch: 13 [448/1924 (23%)], Batch Loss: 0.002271
# Train Epoch: 13 [928/1924 (48%)], Batch Loss: 0.000943
# Train Epoch: 13 [1408/1924 (72%)], Batch Loss: 0.001739
# Train Epoch: 13 [1888/1924 (97%)], Batch Loss: 0.003201
# Test epoch: 13, Test batch loss: 0.0558
# Train Epoch: 14 [448/1924 (23%)], Batch Loss: 0.002002
# Train Epoch: 14 [928/1924 (48%)], Batch Loss: 0.001967
# Train Epoch: 14 [1408/1924 (72%)], Batch Loss: 0.002021
# Train Epoch: 14 [1888/1924 (97%)], Batch Loss: 0.001739
# Test epoch: 14, Test batch loss: 0.0381
# Train Epoch: 15 [448/1924 (23%)], Batch Loss: 0.001700
# Train Epoch: 15 [928/1924 (48%)], Batch Loss: 0.001332
# Train Epoch: 15 [1408/1924 (72%)], Batch Loss: 0.001197
# Train Epoch: 15 [1888/1924 (97%)], Batch Loss: 0.001389
# Test epoch: 15, Test batch loss: 0.0418
# Train Epoch: 16 [448/1924 (23%)], Batch Loss: 0.002032
# Train Epoch: 16 [928/1924 (48%)], Batch Loss: 0.001217
# Train Epoch: 16 [1408/1924 (72%)], Batch Loss: 0.002604
# Train Epoch: 16 [1888/1924 (97%)], Batch Loss: 0.002340
# Test epoch: 16, Test batch loss: 0.0352
# Train Epoch: 17 [448/1924 (23%)], Batch Loss: 0.004228
# Train Epoch: 17 [928/1924 (48%)], Batch Loss: 0.001831
# Train Epoch: 17 [1408/1924 (72%)], Batch Loss: 0.001002
# Train Epoch: 17 [1888/1924 (97%)], Batch Loss: 0.000989
# Test epoch: 17, Test batch loss: 0.0369
# Train Epoch: 18 [448/1924 (23%)], Batch Loss: 0.002380
# Train Epoch: 18 [928/1924 (48%)], Batch Loss: 0.002423
# Train Epoch: 18 [1408/1924 (72%)], Batch Loss: 0.001518
# Train Epoch: 18 [1888/1924 (97%)], Batch Loss: 0.001376
# Test epoch: 18, Test batch loss: 0.0342
# Train Epoch: 19 [448/1924 (23%)], Batch Loss: 0.001096
# Train Epoch: 19 [928/1924 (48%)], Batch Loss: 0.001485
# Train Epoch: 19 [1408/1924 (72%)], Batch Loss: 0.001243
# Train Epoch: 19 [1888/1924 (97%)], Batch Loss: 0.001856
# Test epoch: 19, Test batch loss: 0.0380
# Train Epoch: 20 [448/1924 (23%)], Batch Loss: 0.002010
# Train Epoch: 20 [928/1924 (48%)], Batch Loss: 0.001338
# Train Epoch: 20 [1408/1924 (72%)], Batch Loss: 0.001307
# Train Epoch: 20 [1888/1924 (97%)], Batch Loss: 0.001288
# Test epoch: 20, Test batch loss: 0.0338
# Train Epoch: 21 [448/1924 (23%)], Batch Loss: 0.002046
# Train Epoch: 21 [928/1924 (48%)], Batch Loss: 0.000895
# Train Epoch: 21 [1408/1924 (72%)], Batch Loss: 0.001683
# Train Epoch: 21 [1888/1924 (97%)], Batch Loss: 0.000606
# Test epoch: 21, Test batch loss: 0.0331
# Train Epoch: 22 [448/1924 (23%)], Batch Loss: 0.001347
# Train Epoch: 22 [928/1924 (48%)], Batch Loss: 0.001293
# Train Epoch: 22 [1408/1924 (72%)], Batch Loss: 0.001662
# Train Epoch: 22 [1888/1924 (97%)], Batch Loss: 0.000939
# Test epoch: 22, Test batch loss: 0.0285
# Train Epoch: 23 [448/1924 (23%)], Batch Loss: 0.001248
# Train Epoch: 23 [928/1924 (48%)], Batch Loss: 0.000706
# Train Epoch: 23 [1408/1924 (72%)], Batch Loss: 0.000901
# Train Epoch: 23 [1888/1924 (97%)], Batch Loss: 0.001399
# Test epoch: 23, Test batch loss: 0.0308
# Train Epoch: 24 [448/1924 (23%)], Batch Loss: 0.000529
# Train Epoch: 24 [928/1924 (48%)], Batch Loss: 0.000994
# Train Epoch: 24 [1408/1924 (72%)], Batch Loss: 0.001080
# Train Epoch: 24 [1888/1924 (97%)], Batch Loss: 0.001995
# Test epoch: 24, Test batch loss: 0.0273
# Train Epoch: 25 [448/1924 (23%)], Batch Loss: 0.000956
# Train Epoch: 25 [928/1924 (48%)], Batch Loss: 0.001152
# Train Epoch: 25 [1408/1924 (72%)], Batch Loss: 0.000975
# Train Epoch: 25 [1888/1924 (97%)], Batch Loss: 0.001111
# Test epoch: 25, Test batch loss: 0.0208
# Train Epoch: 26 [448/1924 (23%)], Batch Loss: 0.001674
# Train Epoch: 26 [928/1924 (48%)], Batch Loss: 0.001156
# Train Epoch: 26 [1408/1924 (72%)], Batch Loss: 0.001182
# Train Epoch: 26 [1888/1924 (97%)], Batch Loss: 0.000951
# Test epoch: 26, Test batch loss: 0.0240
# Train Epoch: 27 [448/1924 (23%)], Batch Loss: 0.000532
# Train Epoch: 27 [928/1924 (48%)], Batch Loss: 0.001247
# Train Epoch: 27 [1408/1924 (72%)], Batch Loss: 0.001200
# Train Epoch: 27 [1888/1924 (97%)], Batch Loss: 0.001299
# Test epoch: 27, Test batch loss: 0.0294
# Train Epoch: 28 [448/1924 (23%)], Batch Loss: 0.001445
# Train Epoch: 28 [928/1924 (48%)], Batch Loss: 0.001168
# Train Epoch: 28 [1408/1924 (72%)], Batch Loss: 0.001065
# Train Epoch: 28 [1888/1924 (97%)], Batch Loss: 0.001211
# Test epoch: 28, Test batch loss: 0.0252
# Train Epoch: 29 [448/1924 (23%)], Batch Loss: 0.000632
# Train Epoch: 29 [928/1924 (48%)], Batch Loss: 0.001207
# Train Epoch: 29 [1408/1924 (72%)], Batch Loss: 0.001471
# Train Epoch: 29 [1888/1924 (97%)], Batch Loss: 0.001383
# Test epoch: 29, Test batch loss: 0.0193
# Train Epoch: 30 [448/1924 (23%)], Batch Loss: 0.000988
# Train Epoch: 30 [928/1924 (48%)], Batch Loss: 0.000807
# Train Epoch: 30 [1408/1924 (72%)], Batch Loss: 0.000709
# Train Epoch: 30 [1888/1924 (97%)], Batch Loss: 0.000869
# Test epoch: 30, Test batch loss: 0.0234
# Train Epoch: 31 [448/1924 (23%)], Batch Loss: 0.001158
# Train Epoch: 31 [928/1924 (48%)], Batch Loss: 0.000724
# Train Epoch: 31 [1408/1924 (72%)], Batch Loss: 0.001002
# Train Epoch: 31 [1888/1924 (97%)], Batch Loss: 0.000840
# Test epoch: 31, Test batch loss: 0.0411
# Train Epoch: 32 [448/1924 (23%)], Batch Loss: 0.001257
# Train Epoch: 32 [928/1924 (48%)], Batch Loss: 0.001104
# Train Epoch: 32 [1408/1924 (72%)], Batch Loss: 0.001377
# Train Epoch: 32 [1888/1924 (97%)], Batch Loss: 0.000877
# Test epoch: 32, Test batch loss: 0.0184
# Train Epoch: 33 [448/1924 (23%)], Batch Loss: 0.001067
# Train Epoch: 33 [928/1924 (48%)], Batch Loss: 0.000821
# Train Epoch: 33 [1408/1924 (72%)], Batch Loss: 0.001098
# Train Epoch: 33 [1888/1924 (97%)], Batch Loss: 0.000750
# Test epoch: 33, Test batch loss: 0.0245
# Train Epoch: 34 [448/1924 (23%)], Batch Loss: 0.000696
# Train Epoch: 34 [928/1924 (48%)], Batch Loss: 0.000667
# Train Epoch: 34 [1408/1924 (72%)], Batch Loss: 0.000749
# Train Epoch: 34 [1888/1924 (97%)], Batch Loss: 0.000353
# Test epoch: 34, Test batch loss: 0.0211
# Train Epoch: 35 [448/1924 (23%)], Batch Loss: 0.000821
# Train Epoch: 35 [928/1924 (48%)], Batch Loss: 0.000430
# Train Epoch: 35 [1408/1924 (72%)], Batch Loss: 0.000426
# Train Epoch: 35 [1888/1924 (97%)], Batch Loss: 0.000838
# Test epoch: 35, Test batch loss: 0.0213
# Train Epoch: 36 [448/1924 (23%)], Batch Loss: 0.000704
# Train Epoch: 36 [928/1924 (48%)], Batch Loss: 0.000693
# Train Epoch: 36 [1408/1924 (72%)], Batch Loss: 0.001081
# Train Epoch: 36 [1888/1924 (97%)], Batch Loss: 0.000608
# Test epoch: 36, Test batch loss: 0.0261
# Train Epoch: 37 [448/1924 (23%)], Batch Loss: 0.000687
# Train Epoch: 37 [928/1924 (48%)], Batch Loss: 0.000593
# Train Epoch: 37 [1408/1924 (72%)], Batch Loss: 0.000506
# Train Epoch: 37 [1888/1924 (97%)], Batch Loss: 0.001001
# Test epoch: 37, Test batch loss: 0.0166
# Train Epoch: 38 [448/1924 (23%)], Batch Loss: 0.000975
# Train Epoch: 38 [928/1924 (48%)], Batch Loss: 0.000559
# Train Epoch: 38 [1408/1924 (72%)], Batch Loss: 0.000844
# Train Epoch: 38 [1888/1924 (97%)], Batch Loss: 0.000553
# Test epoch: 38, Test batch loss: 0.0185
# Train Epoch: 39 [448/1924 (23%)], Batch Loss: 0.000913
# Train Epoch: 39 [928/1924 (48%)], Batch Loss: 0.000391
# Train Epoch: 39 [1408/1924 (72%)], Batch Loss: 0.000658
# Train Epoch: 39 [1888/1924 (97%)], Batch Loss: 0.000810
# Test epoch: 39, Test batch loss: 0.0141
# Train Epoch: 40 [448/1924 (23%)], Batch Loss: 0.000769
# Train Epoch: 40 [928/1924 (48%)], Batch Loss: 0.000710
# Train Epoch: 40 [1408/1924 (72%)], Batch Loss: 0.000445
# Train Epoch: 40 [1888/1924 (97%)], Batch Loss: 0.000571
# Test epoch: 40, Test batch loss: 0.0158
# Train Epoch: 41 [448/1924 (23%)], Batch Loss: 0.000415
# Train Epoch: 41 [928/1924 (48%)], Batch Loss: 0.000533
# Train Epoch: 41 [1408/1924 (72%)], Batch Loss: 0.000907
# Train Epoch: 41 [1888/1924 (97%)], Batch Loss: 0.000449
# Test epoch: 41, Test batch loss: 0.0072
# Train Epoch: 42 [448/1924 (23%)], Batch Loss: 0.000784
# Train Epoch: 42 [928/1924 (48%)], Batch Loss: 0.000569
# Train Epoch: 42 [1408/1924 (72%)], Batch Loss: 0.000358
# Train Epoch: 42 [1888/1924 (97%)], Batch Loss: 0.000335
# Test epoch: 42, Test batch loss: 0.0127
# Train Epoch: 43 [448/1924 (23%)], Batch Loss: 0.000417
# Train Epoch: 43 [928/1924 (48%)], Batch Loss: 0.000529
# Train Epoch: 43 [1408/1924 (72%)], Batch Loss: 0.000358
# Train Epoch: 43 [1888/1924 (97%)], Batch Loss: 0.000297
# Test epoch: 43, Test batch loss: 0.0171
# Train Epoch: 44 [448/1924 (23%)], Batch Loss: 0.000400
# Train Epoch: 44 [928/1924 (48%)], Batch Loss: 0.000713
# Train Epoch: 44 [1408/1924 (72%)], Batch Loss: 0.001000
# Train Epoch: 44 [1888/1924 (97%)], Batch Loss: 0.000203
# Test epoch: 44, Test batch loss: 0.0081
# Train Epoch: 45 [448/1924 (23%)], Batch Loss: 0.000519
# Train Epoch: 45 [928/1924 (48%)], Batch Loss: 0.000484
# Train Epoch: 45 [1408/1924 (72%)], Batch Loss: 0.000354
# Train Epoch: 45 [1888/1924 (97%)], Batch Loss: 0.000437
# Test epoch: 45, Test batch loss: 0.0092
# Train Epoch: 46 [448/1924 (23%)], Batch Loss: 0.000533
# Train Epoch: 46 [928/1924 (48%)], Batch Loss: 0.000503
# Train Epoch: 46 [1408/1924 (72%)], Batch Loss: 0.000518
# Train Epoch: 46 [1888/1924 (97%)], Batch Loss: 0.000520
# Test epoch: 46, Test batch loss: 0.0171
# Train Epoch: 47 [448/1924 (23%)], Batch Loss: 0.000490
# Train Epoch: 47 [928/1924 (48%)], Batch Loss: 0.000421
# Train Epoch: 47 [1408/1924 (72%)], Batch Loss: 0.000520
# Train Epoch: 47 [1888/1924 (97%)], Batch Loss: 0.000255
# Test epoch: 47, Test batch loss: 0.0171
# Train Epoch: 48 [448/1924 (23%)], Batch Loss: 0.000317
# Train Epoch: 48 [928/1924 (48%)], Batch Loss: 0.000520
# Train Epoch: 48 [1408/1924 (72%)], Batch Loss: 0.000403
# Train Epoch: 48 [1888/1924 (97%)], Batch Loss: 0.000626
# Test epoch: 48, Test batch loss: 0.0051
# Train Epoch: 49 [448/1924 (23%)], Batch Loss: 0.000406
# Train Epoch: 49 [928/1924 (48%)], Batch Loss: 0.000616
# Train Epoch: 49 [1408/1924 (72%)], Batch Loss: 0.000631
# Train Epoch: 49 [1888/1924 (97%)], Batch Loss: 0.000432
# Test epoch: 49, Test batch loss: 0.0103
# Train Epoch: 50 [448/1924 (23%)], Batch Loss: 0.000471
# Train Epoch: 50 [928/1924 (48%)], Batch Loss: 0.000499
# Train Epoch: 50 [1408/1924 (72%)], Batch Loss: 0.000287
# Train Epoch: 50 [1888/1924 (97%)], Batch Loss: 0.000418
# Test epoch: 50, Test batch loss: 0.0120
# Train Epoch: 51 [448/1924 (23%)], Batch Loss: 0.000432
# Train Epoch: 51 [928/1924 (48%)], Batch Loss: 0.000394
# Train Epoch: 51 [1408/1924 (72%)], Batch Loss: 0.000377
# Train Epoch: 51 [1888/1924 (97%)], Batch Loss: 0.000348
# Test epoch: 51, Test batch loss: 0.0102
# Train Epoch: 52 [448/1924 (23%)], Batch Loss: 0.000455
# Train Epoch: 52 [928/1924 (48%)], Batch Loss: 0.000600
# Train Epoch: 52 [1408/1924 (72%)], Batch Loss: 0.000411
# Train Epoch: 52 [1888/1924 (97%)], Batch Loss: 0.000445
# Test epoch: 52, Test batch loss: 0.0145
# Train Epoch: 53 [448/1924 (23%)], Batch Loss: 0.000470
# Train Epoch: 53 [928/1924 (48%)], Batch Loss: 0.000541
# Train Epoch: 53 [1408/1924 (72%)], Batch Loss: 0.000414
# Train Epoch: 53 [1888/1924 (97%)], Batch Loss: 0.000169
# Test epoch: 53, Test batch loss: 0.0123
# Train Epoch: 54 [448/1924 (23%)], Batch Loss: 0.000302
# Train Epoch: 54 [928/1924 (48%)], Batch Loss: 0.000244
# Train Epoch: 54 [1408/1924 (72%)], Batch Loss: 0.000372
# Train Epoch: 54 [1888/1924 (97%)], Batch Loss: 0.000307
# Test epoch: 54, Test batch loss: 0.0101
# Train Epoch: 55 [448/1924 (23%)], Batch Loss: 0.000216
# Train Epoch: 55 [928/1924 (48%)], Batch Loss: 0.000422
# Train Epoch: 55 [1408/1924 (72%)], Batch Loss: 0.000199
# Train Epoch: 55 [1888/1924 (97%)], Batch Loss: 0.000169
# Test epoch: 55, Test batch loss: 0.0095
# Train Epoch: 56 [448/1924 (23%)], Batch Loss: 0.000225
# Train Epoch: 56 [928/1924 (48%)], Batch Loss: 0.000351
# Train Epoch: 56 [1408/1924 (72%)], Batch Loss: 0.000241
# Train Epoch: 56 [1888/1924 (97%)], Batch Loss: 0.000217
# Test epoch: 56, Test batch loss: 0.0082
# Train Epoch: 57 [448/1924 (23%)], Batch Loss: 0.000219
# Train Epoch: 57 [928/1924 (48%)], Batch Loss: 0.000400
# Train Epoch: 57 [1408/1924 (72%)], Batch Loss: 0.000346
# Train Epoch: 57 [1888/1924 (97%)], Batch Loss: 0.000269
# Test epoch: 57, Test batch loss: 0.0091
# Train Epoch: 58 [448/1924 (23%)], Batch Loss: 0.000346
# Train Epoch: 58 [928/1924 (48%)], Batch Loss: 0.000294
# Train Epoch: 58 [1408/1924 (72%)], Batch Loss: 0.000480
# Train Epoch: 58 [1888/1924 (97%)], Batch Loss: 0.000202
# Test epoch: 58, Test batch loss: 0.0062
# Train Epoch: 59 [448/1924 (23%)], Batch Loss: 0.000248
# Train Epoch: 59 [928/1924 (48%)], Batch Loss: 0.000381
# Train Epoch: 59 [1408/1924 (72%)], Batch Loss: 0.000549
# Train Epoch: 59 [1888/1924 (97%)], Batch Loss: 0.000285
# Test epoch: 59, Test batch loss: 0.0111
# Train Epoch: 60 [448/1924 (23%)], Batch Loss: 0.000313
# Train Epoch: 60 [928/1924 (48%)], Batch Loss: 0.000204
# Train Epoch: 60 [1408/1924 (72%)], Batch Loss: 0.000337
# Train Epoch: 60 [1888/1924 (97%)], Batch Loss: 0.000292
# Test epoch: 60, Test batch loss: 0.0118
# Train Epoch: 61 [448/1924 (23%)], Batch Loss: 0.000414
# Train Epoch: 61 [928/1924 (48%)], Batch Loss: 0.000216
# Train Epoch: 61 [1408/1924 (72%)], Batch Loss: 0.000448
# Train Epoch: 61 [1888/1924 (97%)], Batch Loss: 0.000336
# Test epoch: 61, Test batch loss: 0.0069
# Train Epoch: 62 [448/1924 (23%)], Batch Loss: 0.000291
# Train Epoch: 62 [928/1924 (48%)], Batch Loss: 0.000256
# Train Epoch: 62 [1408/1924 (72%)], Batch Loss: 0.000394
# Train Epoch: 62 [1888/1924 (97%)], Batch Loss: 0.000183
# Test epoch: 62, Test batch loss: 0.0091
# Train Epoch: 63 [448/1924 (23%)], Batch Loss: 0.000154
# Train Epoch: 63 [928/1924 (48%)], Batch Loss: 0.000149
# Train Epoch: 63 [1408/1924 (72%)], Batch Loss: 0.000309
# Train Epoch: 63 [1888/1924 (97%)], Batch Loss: 0.000181
# Test epoch: 63, Test batch loss: 0.0100
# Train Epoch: 64 [448/1924 (23%)], Batch Loss: 0.000219
# Train Epoch: 64 [928/1924 (48%)], Batch Loss: 0.000233
# Train Epoch: 64 [1408/1924 (72%)], Batch Loss: 0.000168
# Train Epoch: 64 [1888/1924 (97%)], Batch Loss: 0.000175
# Test epoch: 64, Test batch loss: 0.0050
# Train Epoch: 65 [448/1924 (23%)], Batch Loss: 0.000226
# Train Epoch: 65 [928/1924 (48%)], Batch Loss: 0.000283
# Train Epoch: 65 [1408/1924 (72%)], Batch Loss: 0.000153
# Train Epoch: 65 [1888/1924 (97%)], Batch Loss: 0.000158
# Test epoch: 65, Test batch loss: 0.0085
# Train Epoch: 66 [448/1924 (23%)], Batch Loss: 0.000365
# Train Epoch: 66 [928/1924 (48%)], Batch Loss: 0.000181
# Train Epoch: 66 [1408/1924 (72%)], Batch Loss: 0.000246
# Train Epoch: 66 [1888/1924 (97%)], Batch Loss: 0.000111
# Test epoch: 66, Test batch loss: 0.0051
# Train Epoch: 67 [448/1924 (23%)], Batch Loss: 0.000247
# Train Epoch: 67 [928/1924 (48%)], Batch Loss: 0.000184
# Train Epoch: 67 [1408/1924 (72%)], Batch Loss: 0.000174
# Train Epoch: 67 [1888/1924 (97%)], Batch Loss: 0.000338
# Test epoch: 67, Test batch loss: 0.0046
# Train Epoch: 68 [448/1924 (23%)], Batch Loss: 0.000211
# Train Epoch: 68 [928/1924 (48%)], Batch Loss: 0.000207
# Train Epoch: 68 [1408/1924 (72%)], Batch Loss: 0.000164
# Train Epoch: 68 [1888/1924 (97%)], Batch Loss: 0.000125
# Test epoch: 68, Test batch loss: 0.0106
# Train Epoch: 69 [448/1924 (23%)], Batch Loss: 0.000141
# Train Epoch: 69 [928/1924 (48%)], Batch Loss: 0.000246
# Train Epoch: 69 [1408/1924 (72%)], Batch Loss: 0.000242
# Train Epoch: 69 [1888/1924 (97%)], Batch Loss: 0.000332
# Test epoch: 69, Test batch loss: 0.0075
# Train Epoch: 70 [448/1924 (23%)], Batch Loss: 0.000108
# Train Epoch: 70 [928/1924 (48%)], Batch Loss: 0.000194
# Train Epoch: 70 [1408/1924 (72%)], Batch Loss: 0.000204
# Train Epoch: 70 [1888/1924 (97%)], Batch Loss: 0.000179
# Test epoch: 70, Test batch loss: 0.0071
# Train Epoch: 71 [448/1924 (23%)], Batch Loss: 0.000377
# Train Epoch: 71 [928/1924 (48%)], Batch Loss: 0.000256
# Train Epoch: 71 [1408/1924 (72%)], Batch Loss: 0.000192
# Train Epoch: 71 [1888/1924 (97%)], Batch Loss: 0.000134
# Test epoch: 71, Test batch loss: 0.0093
# Train Epoch: 72 [448/1924 (23%)], Batch Loss: 0.000195
# Train Epoch: 72 [928/1924 (48%)], Batch Loss: 0.000212
# Train Epoch: 72 [1408/1924 (72%)], Batch Loss: 0.000166
# Train Epoch: 72 [1888/1924 (97%)], Batch Loss: 0.000126
# Test epoch: 72, Test batch loss: 0.0079
# Train Epoch: 73 [448/1924 (23%)], Batch Loss: 0.000132
# Train Epoch: 73 [928/1924 (48%)], Batch Loss: 0.000105
# Train Epoch: 73 [1408/1924 (72%)], Batch Loss: 0.000208
# Train Epoch: 73 [1888/1924 (97%)], Batch Loss: 0.000127
# Test epoch: 73, Test batch loss: 0.0043
# Train Epoch: 74 [448/1924 (23%)], Batch Loss: 0.000156
# Train Epoch: 74 [928/1924 (48%)], Batch Loss: 0.000171
# Train Epoch: 74 [1408/1924 (72%)], Batch Loss: 0.000160
# Train Epoch: 74 [1888/1924 (97%)], Batch Loss: 0.000116
# Test epoch: 74, Test batch loss: 0.0046
# Train Epoch: 75 [448/1924 (23%)], Batch Loss: 0.000131
# Train Epoch: 75 [928/1924 (48%)], Batch Loss: 0.000107
# Train Epoch: 75 [1408/1924 (72%)], Batch Loss: 0.000108
# Train Epoch: 75 [1888/1924 (97%)], Batch Loss: 0.000298
# Test epoch: 75, Test batch loss: 0.0047

# %%
# Make predictions
y_train_pred = model(x_train.to(device), prev_close_train.to(device)).to('cpu')
y_test_pred = model(x_test.to(device), prev_close_test.to(device)).to('cpu')

y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy().reshape(-1, 1))[:, 0]
y_train = scaler.inverse_transform(y_train.detach().numpy().reshape(-1, 1))[:, 0]
y_test_pred = scaler.inverse_transform(y_test_pred.detach().numpy().reshape(-1, 1))[:, 0]
y_test = scaler.inverse_transform(y_test.detach().numpy().reshape(-1, 1))[:, 0]

# Calculate RMSE
trainScore = math.sqrt(mean_squared_error(y_train, y_train_pred))
print('Train Score: %.2f RMSE' % trainScore)
testScore = math.sqrt(mean_squared_error(y_test, y_test_pred))
print('Test Score: %.2f RMSE' % testScore)
# Out:
# Train Score: 0.59 RMSE
# Test Score: 3.40 RMSE

# %%
figure, axes = plt.subplots(figsize=(15, 6))
axes.xaxis_date()
axes.plot(stock_data[len(stock_data)-len(y_test):].index, y_test, color = 'red', label = 'real')
axes.plot(stock_data[len(stock_data)-len(y_test):].index, y_test_pred, color = 'blue', label = 'pred')
plt.show()

# %%
torch.cuda.empty_cache()
import gc
gc.collect()
# Out:
# 3647
